# %% [markdown]
# ## Assignment 2b
# Submitted by: IEC2016012

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import timeit

plt.rcParams["figure.figsize"] = (20,6)

# %%
df = pd.read_csv('Housing.csv', index_col='Unnamed: 0')
df.head()
# Out:
#      price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 1  42000.0     5850         3        1        2      yes      no      yes
# 2  38500.0     4000         2        1        1      yes      no       no
# 3  49500.0     3060         3        1        1      yes      no       no
# 4  60500.0     6650         3        1        2      yes     yes       no
# 5  61000.0     6360         2        1        1      yes      no       no
#
#   gashw airco  garagepl prefarea
# 1    no    no         1       no
# 2    no    no         0       no
# 3    no    no         0       no
# 4    no    no         0       no
# 5    no    no         0       no

# %%
df.shape
# Out:
# (546, 12)

# %%
df.describe(include='all')
# Out:
#                 price       lotsize    bedrooms     bathrms     stories  \
# count      546.000000    546.000000  546.000000  546.000000  546.000000
# unique            NaN           NaN         NaN         NaN         NaN
# top               NaN           NaN         NaN         NaN         NaN
# freq              NaN           NaN         NaN         NaN         NaN
# mean     68121.597070   5150.265568    2.965201    1.285714    1.807692
# std      26702.670926   2168.158725    0.737388    0.502158    0.868203
# min      25000.000000   1650.000000    1.000000    1.000000    1.000000
# 25%      49125.000000   3600.000000    2.000000    1.000000    1.000000
# 50%      62000.000000   4600.000000    3.000000    1.000000    2.000000
# 75%      82000.000000   6360.000000    3.000000    2.000000    2.000000
# max     190000.000000  16200.000000    6.000000    4.000000    4.000000
#
#        driveway recroom fullbase gashw airco    garagepl prefarea
# ...

# %%
df.driveway = df.driveway.eq('yes').mul(1)
df.recroom = df.recroom.eq('yes').mul(1)
df.fullbase = df.fullbase.eq('yes').mul(1)
df.gashw = df.gashw.eq('yes').mul(1)
df.airco = df.airco.eq('yes').mul(1)
df.prefarea = df.prefarea.eq('yes').mul(1)

# %%
df.head()
# Out:
#      price  lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase  \
# 1  42000.0     5850         3        1        2         1        0         1
# 2  38500.0     4000         2        1        1         1        0         0
# 3  49500.0     3060         3        1        1         1        0         0
# 4  60500.0     6650         3        1        2         1        1         0
# 5  61000.0     6360         2        1        1         1        0         0
#
#    gashw  airco  garagepl  prefarea
# 1      0      0         1         0
# 2      0      0         0         0
# 3      0      0         0         0
# 4      0      0         0         0
# 5      0      0         0         0

# %% [markdown]
# # Locally Weighted Regression

# %%
X = df[['lotsize']] #,'bedrooms','bathrms', 'stories', 'garagepl'
y = df['price']

# %%
print(X.shape, y.shape)
# Out:
# (546, 1) (546,)

# %%
def lwr(x0, X, y, tau):
    x0 = np.r_[1, x0]
    X = np.c_[np.ones(len(X)), X]

    k = kernel(x0, X, tau)
    w = np.linalg.pinv((X.T*k)@X)@(X.T*k)@y
    
    return x0 @ w

# %%
def kernel(x0, X, tau):
    batch = 20
    tmp = 0
    for i in range(batch//2,X.shape[0]-batch//2):
        tmp += (X[i-10:i+10]-x0)**2
    return np.exp(-tmp/(2*tau**2))

# %%
domain = np.linspace(1000, 17000, num=300)
taus = [0.1,5,20,60,80,150,300,700,1000,2000]
preds = []

for tau in taus:
    pred = [lwr(x0, X, y, tau) for x0 in domain]
    
    plt.plot(domain,pred,X,y,'x')
    plt.title(tau)
    plt.xlabel("Lotsize")
    plt.ylabel("Cost")
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8795e2771369> in <module>
#       4
#       5 for tau in taus:
# ----> 6     pred = [lwr(x0, X, y, tau) for x0 in domain]
#       7
#       8     plt.plot(domain,pred,X,y,'x')
#
# <ipython-input-13-8795e2771369> in <listcomp>(.0)
#       4
#       5 for tau in taus:
# ----> 6     pred = [lwr(x0, X, y, tau) for x0 in domain]
#       7
#       8     plt.plot(domain,pred,X,y,'x')
#
# <ipython-input-9-4441098e8386> in lwr(x0, X, y, tau)
#       4
#       5     k = kernel(x0, X, tau)
# ----> 6     w = np.linalg.pinv((X.T*k)@X)@(X.T*k)@y
#       7
#       8     return x0 @ w
#
# ValueError: operands could not be broadcast together with shapes (2,546) (20,2)

# %%
print("A good value of bandwidth(tau) is: 300")

# %% [markdown]
# ## Conclusion

# %% [markdown]
# It can be inferred that:
#  - A small value of tau would lead to **Overfitting**
#  - Too big a value will falsify the use of this non-parametric algorithm
#  - A good value of tau could be found in the range of 150-300
